# %% [markdown]
# # NYC Taxi Trip Duration - Exploratory Data Analysis (EDA)
#
# ## Data Fields
# - **id**: Unique identifier for each trip
# - **vendor_id**: Code indicating the provider associated with the trip record
# - **pickup_datetime**: Date and time when the meter was engaged
# - **dropoff_datetime**: Date and time when the meter was disengaged
# - **passenger_count**: Number of passengers in the vehicle (driver entered value)
# - **pickup_longitude/latitude**: Coordinates where the meter was engaged
# - **dropoff_longitude/latitude**: Coordinates where the meter was disengaged
# - **store_and_fwd_flag**: Whether trip record was held in vehicle memory (Y/N)
# - **trip_duration**: Duration of the trip in seconds (TARGET)

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings

# Settings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Plot settings
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# Color palette
colors = ['#3498db', '#e74c3c', '#2ecc71', '#9b59b6', '#f39c12', '#1abc9c']
sns.set_palette(colors)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load the training data
DATA_PATH = '../1 project-nyc-taxi-trip-duration/split_sample/'

df_train = pd.read_csv(DATA_PATH + 'train.csv')
df_val = pd.read_csv(DATA_PATH + 'val.csv')
df_test = pd.read_csv(DATA_PATH + 'test.csv')

print(f"Training set: {df_train.shape[0]:,} samples, {df_train.shape[1]} features")
print(f"Validation set: {df_val.shape[0]:,} samples, {df_val.shape[1]} features")
print(f"Test set: {df_test.shape[0]:,} samples, {df_test.shape[1]} features")

# Use training data for EDA
df = df_train.copy()
print(f"\nUsing training set for EDA: {len(df):,} records")
# Out:
# Training set: 5,000 samples, 10 features
# Validation set: 300 samples, 10 features
# Test set: 250 samples, 10 features
#
# Using training set for EDA: 5,000 records
